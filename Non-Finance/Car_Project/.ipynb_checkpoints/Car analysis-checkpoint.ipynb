# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/patrickfahy99/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('final_data')

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df = df.reset_index(drop=True)

# %%
df[df.Rating == df.Rating]
# Out:
#            Make   Model   Price       Rating    Year       Type   Miles  \
# 0          Ford   B-Max   7,850   Good price  2017.0        MPV  21,000
# 1          Ford   B-Max   5,480  Lower price  2013.0        MPV  36,511
# 2          Ford   B-Max   9,000  Great price  2017.0        MPV  17,574
# 3          Ford   B-Max   6,250   Good price  2014.0        MPV  57,513
# 4          Ford   B-Max  10,000   Good price  2017.0        MPV  14,884
# ...         ...     ...     ...          ...     ...        ...     ...
# 313350  Renault  Twingo   5,500   Good price  2015.0  Hatchback  19,813
# 313351  Renault  Twingo   4,350   Good price  2012.0  Hatchback  12,260
# 313352  Renault  Twingo   7,499   Good price  2016.0  Hatchback  13,480
# 313353  Renault  Twingo   5,799   Fair price  2016.0  Hatchback  19,207
# 313354  Renault  Twingo   8,150   Good price  2017.0  Hatchback   8,865
#
#         Litres     BHP Transmission    Fuel  Owners  ULEZ
# 0          1.6   105PS    Automatic  Petrol     NaN  ULEZ
# 1          1.5    75PS       Manual  Diesel     NaN   NaN
# 2          1.6   105PS    Automatic  Petrol     1.0  ULEZ
# 3          1.6  103BHP    Automatic  Petrol     NaN  ULEZ
# 4          1.0   100PS       Manual  Petrol     NaN  ULEZ
# ...        ...     ...          ...     ...     ...   ...
# 313350     1.0    70PS       Manual  Petrol     NaN  ULEZ
# 313351     1.2   75BHP       Manual  Petrol     NaN  ULEZ
# 313352     0.9    90PS    Automatic  Petrol     2.0  ULEZ
# 313353     1.0    70PS       Manual  Petrol     NaN  ULEZ
# 313354     0.9    90PS    Automatic  Petrol     NaN  ULEZ
#
# [216682 rows x 13 columns]

# %%
df.Make.unique()
# Out:
# array(['Ford', 'Audi', 'Bmw', 'Vauxhall', 'Volkswagen', 'Vw', 'Toyota',
#        'Nissan', 'Mercedes-Benz', 'Mercedes', 'Land Rover', 'Honda',
#        'Jaguar', 'Citroen', 'Hyundai', 'Volvo', 'Suzuki', 'Porsche',
#        'Skoda', 'Peugeot', 'Mini', 'Kia', 'Fiat', 'Mazda', 'Mazda2',
#        'Mazda6', 'Mazda3', 'Mitsubishi', 'Renault'], dtype=object)

# %%
def fix_makes(df):
    for i in range(len(df)):
        if 'Mazda6' in df.iloc[i].Make:
            df.at[i, 'Make'] = 'Mazda'
            df.at[i, 'Model'] = 'Mazda6'
        if 'Mazda3' in df.iloc[i].Make:
            df.at[i, 'Make'] = 'Mazda'
            df.at[i, 'Model'] = 'Mazda3'  
        if 'Mazda2' in df.iloc[i].Make:
            df.at[i, 'Make'] = 'Mazda'
            df.at[i, 'Model'] = 'Mazda2'
        if 'Mercedes' in df.iloc[i].Make:
            df.at[i, 'Make'] = 'Mercedes-Benz'
        if 'Vw' in df.iloc[i].Make:
            df.at[i, 'Make'] = 'Volkswagen'
        if i%100 == 0:
            print(i)
    return df

# %%
df = fix_makes(df)
df
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300
# 37400
# 37500
# 37600
# 37700
# 37800
# 37900
# 38000
# 38100
# 38200
# 38300
# 38400
# 38500
# 38600
# 38700
# 38800
# 38900
# 39000
# 39100
# 39200
# 39300
# 39400
# 39500
# 39600
# 39700
# 39800
# 39900
# 40000
# 40100
# 40200
# 40300
# 40400
# 40500
# 40600
# 40700
# 40800
# 40900
# 41000
# 41100
# 41200
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# 42000
# 42100
# 42200
# 42300
# 42400
# 42500
# 42600
# 42700
# 42800
# 42900
# 43000
# 43100
# 43200
# 43300
# 43400
# 43500
# 43600
# 43700
# 43800
# 43900
# 44000
# 44100
# 44200
# 44300
# 44400
# 44500
# 44600
# 44700
# 44800
# 44900
# 45000
# 45100
# 45200
# 45300
# 45400
# 45500
# 45600
# 45700
# 45800
# 45900
# 46000
# 46100
# 46200
# 46300
# 46400
# 46500
# 46600
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# 47300
# 47400
# 47500
# 47600
# 47700
# 47800
# 47900
# 48000
# 48100
# 48200
# 48300
# 48400
# 48500
# 48600
# 48700
# 48800
# 48900
# 49000
# 49100
# 49200
# 49300
# 49400
# 49500
# 49600
# 49700
# 49800
# 49900
# 50000
# 50100
# 50200
# 50300
# 50400
# 50500
# 50600
# 50700
# 50800
# 50900
# 51000
# 51100
# 51200
# 51300
# 51400
# 51500
# 51600
# 51700
# 51800
# 51900
# 52000
# 52100
# 52200
# 52300
# 52400
# 52500
# 52600
# 52700
# 52800
# 52900
# 53000
# 53100
# 53200
# 53300
# 53400
# 53500
# 53600
# 53700
# 53800
# 53900
# 54000
# 54100
# 54200
# 54300
# 54400
# 54500
# 54600
# 54700
# 54800
# 54900
# 55000
# 55100
# 55200
# 55300
# 55400
# 55500
# 55600
# 55700
# 55800
# 55900
# 56000
# 56100
# 56200
# 56300
# 56400
# 56500
# 56600
# 56700
# 56800
# 56900
# 57000
# 57100
# 57200
# 57300
# 57400
# 57500
# 57600
# 57700
# 57800
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# 58500
# 58600
# 58700
# 58800
# 58900
# 59000
# 59100
# 59200
# 59300
# 59400
# 59500
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# 60200
# 60300
# 60400
# 60500
# 60600
# 60700
# 60800
# 60900
# 61000
# 61100
# 61200
# 61300
# 61400
# 61500
# 61600
# 61700
# 61800
# 61900
# 62000
# 62100
# 62200
# 62300
# 62400
# 62500
# 62600
# 62700
# 62800
# 62900
# 63000
# 63100
# 63200
# 63300
# 63400
# 63500
# 63600
# 63700
# 63800
# 63900
# 64000
# 64100
# 64200
# 64300
# 64400
# 64500
# 64600
# 64700
# 64800
# 64900
# 65000
# 65100
# 65200
# 65300
# 65400
# 65500
# 65600
# 65700
# 65800
# 65900
# 66000
# 66100
# 66200
# 66300
# 66400
# 66500
# 66600
# 66700
# 66800
# 66900
# 67000
# 67100
# 67200
# 67300
# 67400
# 67500
# 67600
# 67700
# 67800
# 67900
# 68000
# 68100
# 68200
# 68300
# 68400
# 68500
# 68600
# 68700
# 68800
# 68900
# 69000
# 69100
# 69200
# 69300
# 69400
# 69500
# 69600
# 69700
# 69800
# 69900
# 70000
# 70100
# 70200
# 70300
# 70400
# 70500
# 70600
# 70700
# 70800
# 70900
# 71000
# 71100
# 71200
# 71300
# 71400
# 71500
# 71600
# 71700
# 71800
# 71900
# 72000
# 72100
# 72200
# 72300
# 72400
# 72500
# 72600
# 72700
# 72800
# 72900
# 73000
# 73100
# 73200
# 73300
# 73400
# 73500
# 73600
# 73700
# 73800
# 73900
# 74000
# 74100
# 74200
# 74300
# 74400
# 74500
# 74600
# 74700
# 74800
# 74900
# 75000
# 75100
# 75200
# 75300
# 75400
# 75500
# 75600
# 75700
# 75800
# 75900
# 76000
# 76100
# 76200
# 76300
# 76400
# 76500
# 76600
# 76700
# 76800
# 76900
# 77000
# 77100
# 77200
# 77300
# 77400
# 77500
# 77600
# 77700
# 77800
# 77900
# 78000
# 78100
# 78200
# 78300
# 78400
# 78500
# 78600
# 78700
# 78800
# 78900
# 79000
# 79100
# 79200
# 79300
# 79400
# 79500
# 79600
# 79700
# 79800
# 79900
# 80000
# 80100
# 80200
# 80300
# 80400
# 80500
# 80600
# 80700
# 80800
# 80900
# 81000
# 81100
# 81200
# 81300
# 81400
# 81500
# 81600
# 81700
# 81800
# 81900
# 82000
# 82100
# 82200
# 82300
# 82400
# 82500
# 82600
# 82700
# 82800
# 82900
# 83000
# 83100
# 83200
# 83300
# 83400
# 83500
# 83600
# 83700
# 83800
# 83900
# 84000
# 84100
# 84200
# 84300
# 84400
# 84500
# 84600
# 84700
# 84800
# 84900
# 85000
# 85100
# 85200
# 85300
# 85400
# 85500
# 85600
# 85700
# 85800
# 85900
# 86000
# 86100
# 86200
# 86300
# 86400
# 86500
# 86600
# 86700
# 86800
# 86900
# 87000
# 87100
# 87200
# 87300
# 87400
# 87500
# 87600
# 87700
# 87800
# 87900
# 88000
# 88100
# 88200
# 88300
# 88400
# 88500
# 88600
# 88700
# 88800
# 88900
# 89000
# 89100
# 89200
# 89300
# 89400
# 89500
# 89600
# 89700
# 89800
# 89900
# 90000
# 90100
# 90200
# 90300
# 90400
# 90500
# 90600
# 90700
# 90800
# 90900
# 91000
# 91100
# 91200
# 91300
# 91400
# 91500
# 91600
# 91700
# 91800
# 91900
# 92000
# 92100
# 92200
# 92300
# 92400
# 92500
# 92600
# 92700
# 92800
# 92900
# 93000
# 93100
# 93200
# 93300
# 93400
# 93500
# 93600
# 93700
# 93800
# 93900
# 94000
# 94100
# 94200
# 94300
# 94400
# 94500
# 94600
# 94700
# 94800
# 94900
# 95000
# 95100
# 95200
# 95300
# 95400
# 95500
# 95600
# 95700
# 95800
# 95900
# 96000
# 96100
# 96200
# 96300
# 96400
# 96500
# 96600
# 96700
# 96800
# 96900
# 97000
# 97100
# 97200
# 97300
# 97400
# 97500
# 97600
# 97700
# 97800
# 97900
# 98000
# 98100
# 98200
# 98300
# 98400
# 98500
# 98600
# 98700
# 98800
# 98900
# 99000
# 99100
# 99200
# 99300
# 99400
# 99500
# 99600
# 99700
# 99800
# 99900
# 100000
# 100100
# 100200
# 100300
# 100400
# 100500
# 100600
# 100700
# 100800
# 100900
# 101000
# 101100
# 101200
# 101300
# 101400
# 101500
# 101600
# 101700
# 101800
# 101900
# 102000
# 102100
# 102200
# 102300
# 102400
# 102500
# 102600
# 102700
# 102800
# 102900
# 103000
# 103100
# 103200
# 103300
# 103400
# 103500
# 103600
# 103700
# 103800
# 103900
# 104000
# 104100
# 104200
# 104300
# 104400
# 104500
# 104600
# 104700
# 104800
# 104900
# 105000
# 105100
# 105200
# 105300
# 105400
# 105500
# 105600
# 105700
# 105800
# 105900
# 106000
# 106100
# 106200
# 106300
# 106400
# 106500
# 106600
# 106700
# 106800
# 106900
# 107000
# 107100
# 107200
# 107300
# 107400
# 107500
# 107600
# 107700
# 107800
# 107900
# 108000
# 108100
# 108200
# 108300
# 108400
# 108500
# 108600
# 108700
# 108800
# 108900
# 109000
# 109100
# 109200
# 109300
# 109400
# 109500
# 109600
# 109700
# 109800
# 109900
# 110000
# 110100
# 110200
# 110300
# 110400
# 110500
# 110600
# 110700
# 110800
# 110900
# 111000
# 111100
# 111200
# 111300
# 111400
# 111500
# 111600
# 111700
# 111800
# 111900
# 112000
# 112100
# 112200
# 112300
# 112400
# 112500
# 112600
# 112700
# 112800
# 112900
# 113000
# 113100
# 113200
# 113300
# 113400
# 113500
# 113600
# 113700
# 113800
# 113900
# 114000
# 114100
# 114200
# 114300
# 114400
# 114500
# 114600
# 114700
# 114800
# 114900
# 115000
# 115100
# 115200
# 115300
# 115400
# 115500
# 115600
# 115700
# 115800
# 115900
# 116000
# 116100
# 116200
# 116300
# 116400
# 116500
# 116600
# 116700
# 116800
# 116900
# 117000
# 117100
# 117200
# 117300
# 117400
# 117500
# 117600
# 117700
# 117800
# 117900
# 118000
# 118100
# 118200
# 118300
# 118400
# 118500
# 118600
# 118700
# 118800
# 118900
# 119000
# 119100
# 119200
# 119300
# 119400
# 119500
# 119600
# 119700
# 119800
# 119900
# 120000
# 120100
# 120200
# 120300
# 120400
# 120500
# 120600
# 120700
# 120800
# 120900
# 121000
# 121100
# 121200
# 121300
# 121400
# 121500
# 121600
# 121700
# 121800
# 121900
# 122000
# 122100
# 122200
# 122300
# 122400
# 122500
# 122600
# 122700
# 122800
# 122900
# 123000
# 123100
# 123200
# 123300
# 123400
# 123500
# 123600
# 123700
# 123800
# 123900
# 124000
# 124100
# 124200
# 124300
# 124400
# 124500
# 124600
# 124700
# 124800
# 124900
# 125000
# 125100
# 125200
# 125300
# 125400
# 125500
# 125600
# 125700
# 125800
# 125900
# 126000
# 126100
# 126200
# 126300
# 126400
# 126500
# 126600
# 126700
# 126800
# 126900
# 127000
# 127100
# 127200
# 127300
# 127400
# 127500
# 127600
# 127700
# 127800
# 127900
# 128000
# 128100
# 128200
# 128300
# 128400
# 128500
# 128600
# 128700
# 128800
# 128900
# 129000
# 129100
# 129200
# 129300
# 129400
# 129500
# 129600
# 129700
# 129800
# 129900
# 130000
# 130100
# 130200
# 130300
# 130400
# 130500
# 130600
# 130700
# 130800
# 130900
# 131000
# 291600
# 291700
# 291800
# 291900
# 292000
# 292100
# 292200
# 292300
# 292400
# 292500
# 292600
# 292700
# 292800
# 292900
# 293000
# 293100
# 293200
# 293300
# 293400
# 293500
# 293600
# 293700
# 293800
# 293900
# 294000
# 294100
# 294200
# 294300
# 294400
# 294500
# 294600
# 294700
# 294800
# 294900
# 295000
# 295100
# 295200
# 295300
# 295400
# 295500
# 295600
# 295700
# 295800
# 295900
# 296000
# 296100
# 296200
# 296300
# 296400
# 296500
# 296600
# 296700
# 296800
# 296900
# 297000
# 297100
# 297200
# 297300
# 297400
# 297500
# 297600
# 297700
# 297800
# 297900
# 298000
# 298100
# 298200
# 298300
# 298400
# 298500
# 298600
# 298700
# 298800
# 298900
# 299000
# 299100
# 299200
# 299300
# 299400
# 299500
# 299600
# 299700
# 299800
# 299900
# 300000
# 300100
# 300200
# 300300
# 300400
# 300500
# 300600
# 300700
# 300800
# 300900
# 301000
# 301100
# 301200
# 301300
# 301400
# 301500
# 301600
# 301700
# 301800
# 301900
# 302000
# 302100
# 302200
# 302300
# 302400
# 302500
# 302600
# 302700
# 302800
# 302900
# 303000
# 303100
# 303200
# 303300
# 303400
# 303500
# 303600
# 303700
# 303800
# 303900
# 304000
# 304100
# 304200
# 304300
# 304400
# 304500
# 304600
# 304700
# 304800
# 304900
# 305000
# 305100
# 305200
# 305300
# 305400
# 305500
# 305600
# 305700
# 305800
# 305900
# 306000
# 306100
# 306200
# 306300
# 306400
# 306500
# 306600
# 306700
# 306800
# 306900
# 307000
# 307100
# 307200
# 307300
# 307400
# 307500
# 307600
# 307700
# 307800
# 307900
# 308000
# 308100
# 308200
# 308300
# 308400
# 308500
# 308600
# 308700
# 308800
# 308900
# 309000
# 309100
# 309200
# 309300
# 309400
# 309500
# 309600
# 309700
# 309800
# 309900
# 310000
# 310100
# 310200
# 310300
# 310400
# 310500
# 310600
# 310700
# 310800
# 310900
# 311000
# 311100
# 311200
# 311300
# 311400
# 311500
# 311600
# 311700
# 311800
# 311900
# 312000
# 312100
# 312200
# 312300
# 312400
# 312500
# 312600
# 312700
# 312800
# 312900
# 313000
# 313100
# 313200
# 313300
#            Make   Model   Price       Rating    Year       Type   Miles  \
# 0          Ford   B-Max   7,850   Good price  2017.0        MPV  21,000
# 1          Ford   B-Max   5,480  Lower price  2013.0        MPV  36,511
# 2          Ford   B-Max   9,000  Great price  2017.0        MPV  17,574
# 3          Ford   B-Max   6,250   Good price  2014.0        MPV  57,513
# 4          Ford   B-Max  10,000   Good price  2017.0        MPV  14,884
# ...         ...     ...     ...          ...     ...        ...     ...
# 313350  Renault  Twingo   5,500   Good price  2015.0  Hatchback  19,813
# 313351  Renault  Twingo   4,350   Good price  2012.0  Hatchback  12,260
# 313352  Renault  Twingo   7,499   Good price  2016.0  Hatchback  13,480
# 313353  Renault  Twingo   5,799   Fair price  2016.0  Hatchback  19,207
# 313354  Renault  Twingo   8,150   Good price  2017.0  Hatchback   8,865
#
#         Litres     BHP Transmission    Fuel  Owners  ULEZ
# 0          1.6   105PS    Automatic  Petrol     NaN  ULEZ
# 1          1.5    75PS       Manual  Diesel     NaN   NaN
# 2          1.6   105PS    Automatic  Petrol     1.0  ULEZ
# 3          1.6  103BHP    Automatic  Petrol     NaN  ULEZ
# 4          1.0   100PS       Manual  Petrol     NaN  ULEZ
# ...        ...     ...          ...     ...     ...   ...
# 313350     1.0    70PS       Manual  Petrol     NaN  ULEZ
# 313351     1.2   75BHP       Manual  Petrol     NaN  ULEZ
# 313352     0.9    90PS    Automatic  Petrol     2.0  ULEZ
# 313353     1.0    70PS       Manual  Petrol     NaN  ULEZ
# 313354     0.9    90PS    Automatic  Petrol     NaN  ULEZ
#
# [313355 rows x 13 columns]

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
df[df.Model != df.Model]
# Out:
#          Make Model   Price Rating    Year       Type  Miles  Litres    BHP  \
# 235600  Skoda   NaN  16,990    NaN  2019.0  Hatchback  2,653     1.0  115PS
#
#        Transmission    Fuel  Owners  ULEZ
# 235600       Manual  Petrol     NaN  ULEZ

# %%
def clean_data(df):
    
    df = df.reset_index(drop=True)
    
    df['ULEZ'] = df['ULEZ'].fillna(0)
    d = {'ULEZ': 1}
    df = df.replace({'ULEZ': d})
    
    dfrate = df[df['Rating'] == df['Rating']]
    dfrate.drop_duplicates()
    df = df[df['Rating'] != df['Rating']]
    df = df.append(dfrate.drop_duplicates(), ignore_index=True)
    df = df.drop('Rating', axis=1)
    
    df = df.reset_index(drop=True)
    
    for i in range(len(df)):
        if '£' in df.iloc[i].Price:
            df.at[i, 'Price'] = df.iloc[i].Price.split('\n')[1].split('£')[1]
        
    df['Price'] = df['Price'].str.replace(',', '')
    df['Miles'] = df['Miles'].str.replace(',', '')
    
    df['Price'] = pd.to_numeric(df['Price'], downcast='float')
    df['Miles'] = pd.to_numeric(df['Miles'], downcast='float')
    
    return df

# %%
df = clean_data(df)

# %%
df
# Out:
#            Make   Model   Price    Year       Type    Miles  Litres    BHP  \
# 0          Ford   B-Max  6600.0  2014.0        MPV  48658.0     NaN    NaN
# 1          Ford   B-Max  4985.0  2013.0        MPV  34516.0     1.6  105PS
# 2          Ford   B-Max  7500.0  2016.0        MPV  24000.0     1.0  125PS
# 3          Ford   B-Max  5990.0  2015.0        MPV  10800.0     1.6  105PS
# 4          Ford   B-Max  4999.0  2013.0        MPV  84789.0     1.6  105PS
# ...         ...     ...     ...     ...        ...      ...     ...    ...
# 223773  Renault  Twingo  6995.0  2018.0  Hatchback   4700.0     1.0   70PS
# 223774  Renault  Twingo  6265.0  2016.0  Hatchback  23934.0     1.0   70PS
# 223775  Renault  Twingo  5700.0  2016.0  Hatchback  24769.0     1.0   70PS
# 223776  Renault  Twingo  4495.0  2013.0  Hatchback  31924.0     1.2  75BHP
# 223777  Renault  Twingo  5995.0  2017.0  Hatchback  13356.0     1.0   70PS
#
#        Transmission    Fuel  Owners  ULEZ
# 0            Manual  Petrol     NaN     0
# 1         Automatic  Petrol     5.0     1
# 2            Manual  Petrol     2.0     1
# 3         Automatic  Petrol     3.0     1
# 4         Automatic  Petrol     2.0     1
# ...             ...     ...     ...   ...
# 223773       Manual  Petrol     NaN     1
# 223774       Manual  Petrol     1.0     1
# 223775       Manual  Petrol     NaN     1
# 223776       Manual  Petrol     NaN     1
# 223777       Manual  Petrol     NaN     1
#
# [223778 rows x 12 columns]

# %%
df2 = df[df.Make == 'Skoda']
df3 = df2[df2['BHP'] == '115PS']
df4 = df3[df3.Litres == 1.0]
df5 = df4[df4.Price > 16980]
df6 = df5[df5.Price < 17000]
df5['Model'].value_counts()
# Out:
# Kamiq    280
# Scala    176
# Karoq    124
# Skoda     13
# Name: Model, dtype: int64

# %% [markdown]
# mehhhh let's drop it

# %%
df = df.drop(df[df.Model != df.Model].index)
df = df.reset_index(drop=True)

# %%
df = df.drop(df[df.Transmission != df.Transmission].index, axis=0)

# %%
df = df.reset_index(drop=True)
df
# Out:
#            Make   Model   Price    Year       Type    Miles  Litres    BHP  \
# 0          Ford   B-Max  6600.0  2014.0        MPV  48658.0     NaN    NaN
# 1          Ford   B-Max  4985.0  2013.0        MPV  34516.0     1.6  105PS
# 2          Ford   B-Max  7500.0  2016.0        MPV  24000.0     1.0  125PS
# 3          Ford   B-Max  5990.0  2015.0        MPV  10800.0     1.6  105PS
# 4          Ford   B-Max  4999.0  2013.0        MPV  84789.0     1.6  105PS
# ...         ...     ...     ...     ...        ...      ...     ...    ...
# 223687  Renault  Twingo  6995.0  2018.0  Hatchback   4700.0     1.0   70PS
# 223688  Renault  Twingo  6265.0  2016.0  Hatchback  23934.0     1.0   70PS
# 223689  Renault  Twingo  5700.0  2016.0  Hatchback  24769.0     1.0   70PS
# 223690  Renault  Twingo  4495.0  2013.0  Hatchback  31924.0     1.2  75BHP
# 223691  Renault  Twingo  5995.0  2017.0  Hatchback  13356.0     1.0   70PS
#
#        Transmission    Fuel  Owners  ULEZ
# 0            Manual  Petrol     NaN     0
# 1         Automatic  Petrol     5.0     1
# 2            Manual  Petrol     2.0     1
# 3         Automatic  Petrol     3.0     1
# 4         Automatic  Petrol     2.0     1
# ...             ...     ...     ...   ...
# 223687       Manual  Petrol     NaN     1
# 223688       Manual  Petrol     1.0     1
# 223689       Manual  Petrol     NaN     1
# 223690       Manual  Petrol     NaN     1
# 223691       Manual  Petrol     NaN     1
#
# [223692 rows x 12 columns]

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.countplot(x='Type', data=df, ax=ax)

# %%
df[df.Miles != df.Miles]
# Out:
#           Make     Model    Price  Year Type  Miles  Litres    BHP  \
# 1260      Ford  Ecosport  22900.0   NaN  SUV    NaN     1.0  125PS
# 1267      Ford  Ecosport  21950.0   NaN  SUV    NaN     1.0  125PS
# 1268      Ford  Ecosport  22900.0   NaN  SUV    NaN     1.0  125PS
# 1269      Ford  Ecosport  21000.0   NaN  SUV    NaN     1.0  125PS
# 1273      Ford  Ecosport  23500.0   NaN  SUV    NaN     1.0  140PS
# ...        ...       ...      ...   ...  ...    ...     ...    ...
# 96015  Renault       All  23455.0   NaN  SUV    NaN     1.3  130PS
# 96020  Renault       All  27945.0   NaN  SUV    NaN     1.3  155PS
# 96021  Renault    Captur  26355.0   NaN  SUV    NaN     1.5  115PS
# 96023  Renault       All  27154.0   NaN  SUV    NaN     1.3  155PS
# 96148  Renault    Scenic  24015.0   NaN  MPV    NaN     1.3  140PS
#
#       Transmission    Fuel  Owners  ULEZ
# 1260        Manual  Petrol     NaN     1
# 1267        Manual  Petrol     NaN     1
# 1268        Manual  Petrol     NaN     1
# 1269     Automatic  Petrol     NaN     1
# 1273        Manual  Petrol     NaN     1
# ...            ...     ...     ...   ...
# 96015    Automatic  Petrol     NaN     1
# 96020    Automatic  Petrol     NaN     1
# 96021    Automatic  Diesel     NaN     1
# 96023    Automatic  Petrol     NaN     1
# 96148       Manual  Petrol     NaN     1
#
# [18056 rows x 12 columns]

# %%
dfnyr = df[df.Year != df.Year]
dfnboth = dfnyr[df.Miles != df.Miles]
dfnboth
df = df.drop(dfnboth.index).reset_index(drop=True)
# Out:
# /Users/patrickfahy99/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
sns.barplot(x='Transmission', y='Price', data=df)

# %%
fig_dims = (10, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='Type', y='Price', data=df, ax=ax)

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
df[df.Miles != df.Miles]
# Out:
#              Make   Model    Price    Year         Type  Miles  Litres  \
# 3722         Ford     Ka+  12890.0  2019.0    Hatchback    NaN     1.2
# 4489         Ford  Ranger   7995.0  2011.0       Pickup    NaN     2.5
# 4647         Ford  Ranger  28776.0  2020.0       Pickup    NaN     2.0
# 4702         Ford  Ranger  28776.0  2020.0       Pickup    NaN     2.0
# 4748         Ford  Ranger  23980.0  2018.0       Pickup    NaN     3.2
# ...           ...     ...      ...     ...          ...    ...     ...
# 74715  Mitsubishi  Mirage   9500.0  2020.0    Hatchback    NaN     1.2
# 77068     Renault    Clio   1500.0  2012.0    Hatchback    NaN     1.2
# 77429     Renault  Megane   5990.0  2010.0  Convertible    NaN     1.9
# 78119     Renault  Captur   8499.0  2017.0          SUV    NaN     1.5
# 78159     Renault  Captur  11995.0  2019.0          SUV    NaN     1.5
#
#           BHP Transmission    Fuel  Owners  ULEZ
# 3722     85PS       Manual  Petrol     NaN     1
# 4489   140BHP       Manual  Diesel     NaN     0
# 4647    170PS       Manual  Diesel     NaN     1
# 4702    170PS       Manual  Diesel     NaN     1
# 4748    200PS    Automatic  Diesel     NaN     0
# ...       ...          ...     ...     ...   ...
# 74715    80PS       Manual  Petrol     NaN     1
# 77068   75BHP       Manual  Petrol     NaN     1
# 77429  130BHP       Manual  Diesel     2.0     0
# 78119    90PS       Manual  Diesel     NaN     1
# 78159    90PS       Manual  Diesel     NaN     1
#
# [196 rows x 12 columns]

# %%
sns.distplot(df.Year)

# %%
def year_outlier(yr, df):
    
    dfyrout = df[df.Year < yr]
    df = df.drop(dfyrout.index).reset_index(drop=True)
    
    return df

df = year_outlier(1997, df)

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='Year', y='Miles', data=df, ax=ax)

# %%
dfnmil = df[df.Miles != df.Miles]
dfnmil
# Out:
#              Make   Model    Price    Year         Type  Miles  Litres  \
# 3709         Ford     Ka+  12890.0  2019.0    Hatchback    NaN     1.2
# 4476         Ford  Ranger   7995.0  2011.0       Pickup    NaN     2.5
# 4634         Ford  Ranger  28776.0  2020.0       Pickup    NaN     2.0
# 4689         Ford  Ranger  28776.0  2020.0       Pickup    NaN     2.0
# 4735         Ford  Ranger  23980.0  2018.0       Pickup    NaN     3.2
# ...           ...     ...      ...     ...          ...    ...     ...
# 74086  Mitsubishi  Mirage   9500.0  2020.0    Hatchback    NaN     1.2
# 76439     Renault    Clio   1500.0  2012.0    Hatchback    NaN     1.2
# 76799     Renault  Megane   5990.0  2010.0  Convertible    NaN     1.9
# 77489     Renault  Captur   8499.0  2017.0          SUV    NaN     1.5
# 77529     Renault  Captur  11995.0  2019.0          SUV    NaN     1.5
#
#           BHP Transmission    Fuel  Owners  ULEZ
# 3709     85PS       Manual  Petrol     NaN     1
# 4476   140BHP       Manual  Diesel     NaN     0
# 4634    170PS       Manual  Diesel     NaN     1
# 4689    170PS       Manual  Diesel     NaN     1
# 4735    200PS    Automatic  Diesel     NaN     0
# ...       ...          ...     ...     ...   ...
# 74086    80PS       Manual  Petrol     NaN     1
# 76439   75BHP       Manual  Petrol     NaN     1
# 76799  130BHP       Manual  Diesel     2.0     0
# 77489    90PS       Manual  Diesel     NaN     1
# 77529    90PS       Manual  Diesel     NaN     1
#
# [193 rows x 12 columns]

# %%
df[df.Year == df.iloc[1].Year].Miles.mean()
# Out:
# 67026.90625

# %%
for i in range(len(df)):
    if df.iloc[i].Miles != df.iloc[i].Miles:
        df.at[i, 'Miles'] = df[df.Year == df.iloc[i].Year].Miles.mean()
    if i%1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000

# %%
df[df.Year != df.Year]
# Out:
#           Make  Model    Price  Year       Type    Miles  Litres  BHP  \
# 20        Ford  B-Max   6600.0   NaN        MPV  46000.0     NaN  NaN
# 23        Ford  B-Max   6600.0   NaN        MPV  46000.0     NaN  NaN
# 26        Ford  B-Max   6600.0   NaN        MPV  46000.0     NaN  NaN
# 35        Ford  B-Max   6600.0   NaN        MPV  46000.0     NaN  NaN
# 43        Ford  B-Max   6600.0   NaN        MPV  46000.0     NaN  NaN
# ...        ...    ...      ...   ...        ...      ...     ...  ...
# 76927  Renault    Zoe   7990.0   NaN  Hatchback  14600.0     NaN  NaN
# 76961  Renault    Zoe  13490.0   NaN  Hatchback  25880.0     NaN  NaN
# 76962  Renault    Zoe  13990.0   NaN  Hatchback  14725.0     NaN  NaN
# 76966  Renault    Zoe  16990.0   NaN  Hatchback  12124.0     NaN  NaN
# 76967  Renault    Zoe  17990.0   NaN  Hatchback  27876.0     NaN  NaN
#
#       Transmission    Fuel  Owners  ULEZ
# 20          Manual  Petrol     NaN     0
# 23          Manual  Petrol     NaN     0
# 26          Manual  Petrol     NaN     0
# 35          Manual  Petrol     NaN     0
# 43          Manual  Petrol     NaN     0
# ...            ...     ...     ...   ...
# 76927    Automatic     NaN     2.0     0
# 76961    Automatic     NaN     1.0     0
# 76962    Automatic     NaN     1.0     0
# 76966    Automatic     NaN     2.0     0
# 76967    Automatic     NaN     1.0     0
#
# [266 rows x 12 columns]

# %%
d = {1997: '', 1998: '', 1999: '', 2000: '', 2001: '', 2002: '', 2003: '', 2004: '', 2005: '', 2006: '',
    2007: '', 2008: '', 2009: '', 2010: '', 2011: '', 2012: '', 2013: '', 2014: '', 2015: '', 2016: '',
    2017: '', 2018: '', 2019: '', 2020: ''}
for key, value in d.items():
    d[key] = df[df.Year == key].Miles.mean()
d
# Out:
# {1997: 102906.171875,
#  1998: 105770.5390625,
#  1999: 98753.7421875,
#  2000: 105133.03125,
#  2001: 104200.6328125,
#  2002: 96253.71875,
#  2003: 102705.25,
#  2004: 97040.3046875,
#  2005: 99787.765625,
#  2006: 96293.140625,
#  2007: 95698.296875,
#  2008: 90750.1640625,
#  2009: 85254.2265625,
#  2010: 82548.21875,
#  2011: 78901.9453125,
#  2012: 72038.59375,
#  2013: 67026.8984375,
#  2014: 55550.0,
#  2015: 48115.1171875,
#  2016: 37877.24609375,
#  2017: 27961.56640625,
#  2018: 18007.76953125,
#  2019: 7233.79541015625,
#  2020: 2574.14453125}

# %%
d.values()
# Out:
# dict_values([102906.171875, 105770.5390625, 98753.7421875, 105133.03125, 104200.6328125, 96253.71875, 102705.25, 97040.3046875, 99787.765625, 96293.140625, 95698.296875, 90750.1640625, 85254.2265625, 82548.21875, 78901.9453125, 72038.59375, 67026.8984375, 55550.0, 48115.1171875, 37877.24609375, 27961.56640625, 18007.76953125, 7233.79541015625, 2574.14453125])

# %%
for i in range(len(df)):
    if df.iloc[i].Year != df.iloc[i].Year:
        search = min(d.values(), key=lambda x:abs(x-df.iloc[i].Miles))
        for key, value in d.items():
            if value == search:
                df.at[i, 'Year'] = key
    if i%1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000

# %%
df.Year.unique()
# Out:
# array([2014., 2013., 2016., 2015., 2017., 2012., 2018., 2002., 2007.,
#        2008., 2011., 2009., 2006., 2010., 2003., 2005., 2001., 2019.,
#        2004., 1998., 2020., 2000., 1999., 1997.])

# %%
df.corr()
# Out:
#            Price      Year     Miles    Litres    Owners      ULEZ
# Price   1.000000  0.521858 -0.479533  0.414701 -0.320892  0.222924
# Year    0.521858  1.000000 -0.735888 -0.199322 -0.642673  0.460485
# Miles  -0.479533 -0.735888  1.000000  0.198395  0.503325 -0.473863
# Litres  0.414701 -0.199322  0.198395  1.000000  0.214453 -0.236203
# Owners -0.320892 -0.642673  0.503325  0.214453  1.000000 -0.297659
# ULEZ    0.222924  0.460485 -0.473863 -0.236203 -0.297659  1.000000

# %%
sns.set_style("whitegrid")
missing = df.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
df[df.Type != df.Type]
# Out:
#                  Make Model    Price    Year Type    Miles  Litres    BHP  \
# 146              Ford    Ka   6200.0  2015.0  NaN  29803.0     NaN    NaN
# 152              Ford    Ka   6200.0  2015.0  NaN  14714.0     NaN    NaN
# 189              Ford    Ka    450.0  2004.0  NaN  71000.0     1.3  59BHP
# 206              Ford    Ka   3100.0  2011.0  NaN  54500.0     NaN    NaN
# 216              Ford    Ka   3100.0  2011.0  NaN  54500.0     NaN    NaN
# ...               ...   ...      ...     ...  ...      ...     ...    ...
# 138058  Mercedes-Benz     V  47995.0  2018.0  NaN  12000.0     2.2  190PS
# 138059  Mercedes-Benz     V  48500.0  2018.0  NaN   4500.0     2.2  163PS
# 138060  Mercedes-Benz     V  47495.0  2019.0  NaN   3450.0     2.2  163PS
# 138061  Mercedes-Benz     V  41995.0  2018.0  NaN   2250.0     2.2  190PS
# 138062  Mercedes-Benz  V250  49500.0  2019.0  NaN    350.0     2.2  190PS
#
#        Transmission    Fuel  Owners  ULEZ
# 146          Manual  Petrol     2.0     0
# 152          Manual  Petrol     2.0     0
# 189          Manual  Petrol     2.0     0
# 206          Manual  Petrol     NaN     0
# 216          Manual  Petrol     NaN     0
# ...             ...     ...     ...   ...
# 138058    Automatic  Diesel     1.0     1
# 138059    Automatic  Diesel     1.0     1
# 138060    Automatic  Diesel     1.0     1
# 138061    Automatic  Diesel     2.0     1
# 138062    Automatic  Diesel     1.0     1
#
# [3248 rows x 12 columns]

# %%
fig_dims = (20, 4)
fig, ax = plt.subplots(figsize=fig_dims)
sns.barplot(x='Owners', y='Price', data=df, ax=ax)

# %% [markdown]
# Let's ignore the car model for now

# %%
data = df.drop('Model', axis=1)

# %%
data[data.Type != data.Type]
# Out:
#                  Make    Price    Year Type    Miles  Litres    BHP  \
# 146              Ford   6200.0  2015.0  NaN  29803.0     NaN    NaN
# 152              Ford   6200.0  2015.0  NaN  14714.0     NaN    NaN
# 189              Ford    450.0  2004.0  NaN  71000.0     1.3  59BHP
# 206              Ford   3100.0  2011.0  NaN  54500.0     NaN    NaN
# 216              Ford   3100.0  2011.0  NaN  54500.0     NaN    NaN
# ...               ...      ...     ...  ...      ...     ...    ...
# 138058  Mercedes-Benz  47995.0  2018.0  NaN  12000.0     2.2  190PS
# 138059  Mercedes-Benz  48500.0  2018.0  NaN   4500.0     2.2  163PS
# 138060  Mercedes-Benz  47495.0  2019.0  NaN   3450.0     2.2  163PS
# 138061  Mercedes-Benz  41995.0  2018.0  NaN   2250.0     2.2  190PS
# 138062  Mercedes-Benz  49500.0  2019.0  NaN    350.0     2.2  190PS
#
#        Transmission    Fuel  Owners  ULEZ
# 146          Manual  Petrol     2.0     0
# 152          Manual  Petrol     2.0     0
# 189          Manual  Petrol     2.0     0
# 206          Manual  Petrol     NaN     0
# 216          Manual  Petrol     NaN     0
# ...             ...     ...     ...   ...
# 138058    Automatic  Diesel     1.0     1
# 138059    Automatic  Diesel     1.0     1
# 138060    Automatic  Diesel     1.0     1
# 138061    Automatic  Diesel     2.0     1
# 138062    Automatic  Diesel     1.0     1
#
# [3248 rows x 11 columns]

# %%
data = data.drop(data[data.Type != data.Type].index)
data = data.drop(data[data.Fuel != data.Fuel].index)
data = data.drop(data[data.Litres != data.Litres].index)
data = data.drop(data[data.BHP != data.BHP].index).reset_index(drop=True)

# %%
def clean_bhp(df):
    
    df = df.reset_index(drop=True)
    
    for i in range(len(df)):
        if 'PS' in df.iloc[i]['BHP']:
            ps = float(df.iloc[i]['BHP'][:-2])
            bhp = ps/1.014
            new = str(bhp) + 'BHP'
            df.at[i, 'BHP'] = new
    for i in range(len(df)):
        df.at[i, 'BHP'] = int(round(float(df.iloc[i]['BHP'][:-3])))
    
    df['BHP'] = pd.to_numeric(df['BHP'], downcast='signed')
    
    return df

# %%
data = clean_bhp(data)

# %%
sns.set_style("whitegrid")
missing = data.isnull().sum()
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing.plot.bar()

# %%
sns.countplot(data.Owners)

# %%
data = data[data.Owners <= 11]

# %%
sns.countplot(data.Owners)

# %%
data = data[data.Owners <= 5]

# %%
sns.countplot(data.Owners)

# %%
sns.barplot(x='Owners', y='Price', data=data)

# %%
sns.countplot(x='Owners', data=data)

# %%
len(data)
# Out:
# 97214

# %%
data.Owners = data.Owners.fillna(2)

# %%
data['2+_Owners'] = data['Owners'] > 1
data['1_Owner'] = data['Owners'] == 1
d = {True: 1, False: 0}
data= data.replace(d)
data
# Out:
#            Make   Price    Year       Type    Miles  Litres  BHP Transmission  \
# 0          Ford  4985.0  2013.0        MPV  34516.0     1.6  104    Automatic
# 1          Ford  7500.0  2016.0        MPV  24000.0     1.0  123       Manual
# 2          Ford  5990.0  2015.0        MPV  10800.0     1.6  104    Automatic
# 3          Ford  4999.0  2013.0        MPV  84789.0     1.6  104    Automatic
# 4          Ford  9999.0  2016.0        MPV   9372.0     1.6  104    Automatic
# ...         ...     ...     ...        ...      ...     ...  ...          ...
# 191426  Renault  7250.0  2018.0  Hatchback   9260.0     1.0   69       Manual
# 191428  Renault  5500.0  2016.0  Hatchback  33516.0     1.0   69       Manual
# 191429  Renault  6949.0  2016.0  Hatchback  13000.0     0.9   89       Manual
# 191434  Renault  5495.0  2015.0  Hatchback  25000.0     1.0   69       Manual
# 191440  Renault  6265.0  2016.0  Hatchback  23934.0     1.0   69       Manual
#
#           Fuel  Owners  ULEZ  2+_Owners  1_Owner
# 0       Petrol     5.0     1          1        0
# 1       Petrol     2.0     1          1        0
# 2       Petrol     3.0     1          1        0
# 3       Petrol     2.0     1          1        0
# 4       Petrol     1.0     1          0        1
# ...        ...     ...   ...        ...      ...
# 191426  Petrol     1.0     1          0        1
# 191428  Petrol     1.0     1          0        1
# 191429  Petrol     2.0     1          1        0
# 191434  Petrol     2.0     1          1        0
# 191440  Petrol     1.0     1          0        1
#
# [97214 rows x 13 columns]

# %%
data = data.drop('Owners', axis=1)

# %%
sns.distplot(data[data['Price']<50000]['Price'])

# %%
data = data[data['Price']<50000]

# %%
data.Price.skew()
# Out:
# 1.3799186

# %%
data['log_price'] = np.log(data.Price)

# %%
sns.distplot(data.log_price)

# %%
data.log_price.skew()
# Out:
# -0.5371626

# %%
data['sqrt_price'] = np.sqrt(data.Price)

# %%
data.sqrt_price.skew()
# Out:
# 0.4777897

# %%
sns.distplot(data.sqrt_price)

# %%
data = data.drop('log_price', axis=1)

# %%
sns.distplot(data[data.Miles < 200000].Miles)

# %%
data = data[data.Miles<200000]

# %%
data.Miles.skew()
# Out:
# 0.717567

# %%
data['sqrt_miles'] = np.sqrt(data.Miles)
data['log_miles'] = np.log(data.Miles)

# %%
print(data.sqrt_miles.skew())
sns.distplot(data.sqrt_miles)
# Out:
# -0.1286915

# %%
print(data.log_miles.skew())
sns.distplot(data.log_miles)
# Out:
# -2.6898665

# %%
data = data.drop('log_miles', axis=1)

# %%
data
# Out:
#            Make   Price    Year       Type    Miles  Litres  BHP Transmission  \
# 0          Ford  4985.0  2013.0        MPV  34516.0     1.6  104    Automatic
# 1          Ford  7500.0  2016.0        MPV  24000.0     1.0  123       Manual
# 2          Ford  5990.0  2015.0        MPV  10800.0     1.6  104    Automatic
# 3          Ford  4999.0  2013.0        MPV  84789.0     1.6  104    Automatic
# 4          Ford  9999.0  2016.0        MPV   9372.0     1.6  104    Automatic
# ...         ...     ...     ...        ...      ...     ...  ...          ...
# 191426  Renault  7250.0  2018.0  Hatchback   9260.0     1.0   69       Manual
# 191428  Renault  5500.0  2016.0  Hatchback  33516.0     1.0   69       Manual
# 191429  Renault  6949.0  2016.0  Hatchback  13000.0     0.9   89       Manual
# 191434  Renault  5495.0  2015.0  Hatchback  25000.0     1.0   69       Manual
# 191440  Renault  6265.0  2016.0  Hatchback  23934.0     1.0   69       Manual
#
#           Fuel  ULEZ  2+_Owners  1_Owner  sqrt_price  sqrt_miles
# 0       Petrol     1          1        0   70.604530  185.784821
# 1       Petrol     1          1        0   86.602539  154.919327
# 2       Petrol     1          1        0   77.395088  103.923050
# 3       Petrol     1          1        0   70.703606  291.185516
# 4       Petrol     1          0        1   99.995003   96.809090
# ...        ...   ...        ...      ...         ...         ...
# 191426  Petrol     1          0        1   85.146935   96.228897
# 191428  Petrol     1          0        1   74.161987  183.073761
# 191429  Petrol     1          1        0   83.360664  114.017540
# 191434  Petrol     1          1        0   74.128265  158.113876
# 191440  Petrol     1          0        1   79.151756  154.706177
#
# [95416 rows x 14 columns]

# %%
data['age'] = 2021 - data['Year']

# %%
data
# Out:
#            Make   Price    Year       Type    Miles  Litres  BHP Transmission  \
# 0          Ford  4985.0  2013.0        MPV  34516.0     1.6  104    Automatic
# 1          Ford  7500.0  2016.0        MPV  24000.0     1.0  123       Manual
# 2          Ford  5990.0  2015.0        MPV  10800.0     1.6  104    Automatic
# 3          Ford  4999.0  2013.0        MPV  84789.0     1.6  104    Automatic
# 4          Ford  9999.0  2016.0        MPV   9372.0     1.6  104    Automatic
# ...         ...     ...     ...        ...      ...     ...  ...          ...
# 191426  Renault  7250.0  2018.0  Hatchback   9260.0     1.0   69       Manual
# 191428  Renault  5500.0  2016.0  Hatchback  33516.0     1.0   69       Manual
# 191429  Renault  6949.0  2016.0  Hatchback  13000.0     0.9   89       Manual
# 191434  Renault  5495.0  2015.0  Hatchback  25000.0     1.0   69       Manual
# 191440  Renault  6265.0  2016.0  Hatchback  23934.0     1.0   69       Manual
#
#           Fuel  ULEZ  2+_Owners  1_Owner  sqrt_price  sqrt_miles  age
# 0       Petrol     1          1        0   70.604530  185.784821  8.0
# 1       Petrol     1          1        0   86.602539  154.919327  5.0
# 2       Petrol     1          1        0   77.395088  103.923050  6.0
# 3       Petrol     1          1        0   70.703606  291.185516  8.0
# 4       Petrol     1          0        1   99.995003   96.809090  5.0
# ...        ...   ...        ...      ...         ...         ...  ...
# 191426  Petrol     1          0        1   85.146935   96.228897  3.0
# 191428  Petrol     1          0        1   74.161987  183.073761  5.0
# 191429  Petrol     1          1        0   83.360664  114.017540  5.0
# 191434  Petrol     1          1        0   74.128265  158.113876  6.0
# 191440  Petrol     1          0        1   79.151756  154.706177  5.0
#
# [95416 rows x 15 columns]

# %%
sns.distplot(data.age)

# %%
data['sqrt_age'] = np.sqrt(data.age)
data['log_age'] = np.log(data.age)

# %%
print(data.sqrt_age.skew())
sns.distplot(data.sqrt_age)
# Out:
# 0.2069010825782243

# %%
print(data.log_age.skew())
sns.distplot(data.log_age)
# Out:
# -0.4829718728212735

# %%
data = data.drop('log_age', axis=1)

# %%
data.to_csv('final_cleaned')
