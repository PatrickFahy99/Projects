# %%
import pandas as pd

# %%
df = pd.read_csv('car_data')

# %%
df.head()
# Out:
#    Unnamed: 0     makes   Price       Rating                    Year  \
# 0           0      Ford  £6,922   Good price                    2016
# 1           1   Hyundai    £890          NaN                    2007
# 2           2   Peugeot  £1,000          NaN                    2004
# 3           3  Vauxhall  £2,000  Great price                    2009
# 4           4  Vauxhall  £1,500          NaN  \n\nCAT\n\n\nWrite-off
#
#             Type          Miles        Litres    BHP Transmission    Fuel
# 0      Hatchback   28,122 miles         1.25L  81BHP       Manual  Petrol
# 1      Hatchback   55,083 miles          1.1L  62BHP       Manual  Petrol
# 2      Hatchback  104,500 miles          1.4L  88BHP       Manual  Petrol
# 3      Hatchback  131,500 miles          1.6L  115PS       Manual  Petrol
# 4  2010 (10 reg)      Hatchback  94,000 miles   1.2L        84BHP  Manual

# %%
df.Fuel.unique()
# Out:
# array(['Petrol', 'Manual', 'Diesel'], dtype=object)

# %%
df.head(50)
# Out:
#     Unnamed: 0          makes    Price        Rating                    Year  \
# 0            0           Ford   £6,922    Good price                    2016
# 1            1        Hyundai     £890           NaN                    2007
# 2            2        Peugeot   £1,000           NaN                    2004
# 3            3       Vauxhall   £2,000   Great price                    2009
# 4            4       Vauxhall   £1,500           NaN  \n\nCAT\n\n\nWrite-off
# 5            5     Volkswagen     £650           NaN                    2001
# 6            6       Vauxhall     £500           NaN                    2006
# 7            7           Saab   £1,795   Lower price                    2009
# 8            8         Toyota   £1,000           NaN                    1999
# 9            9     Volkswagen   £1,958           NaN                    2006
# 10          10        Peugeot     £850           NaN                    2005
# ...

# %%
df[df.Fuel == 'Manual'].Year.unique()
# Out:
# array(['\n\nCAT\n\n\nWrite-off'], dtype=object)

# %% [markdown]
# The only cars with the wrong entries are written off, let's remove them

# %%
df = df[df.Fuel != 'Manual']

# %%
df.reset_index(drop=True)
df.head()
# Out:
#    Unnamed: 0       makes   Price       Rating  Year       Type  \
# 0           0        Ford  £6,922   Good price  2016  Hatchback
# 1           1     Hyundai    £890          NaN  2007  Hatchback
# 2           2     Peugeot  £1,000          NaN  2004  Hatchback
# 3           3    Vauxhall  £2,000  Great price  2009  Hatchback
# 5           5  Volkswagen    £650          NaN  2001     Saloon
#
#            Miles Litres     BHP Transmission    Fuel
# 0   28,122 miles  1.25L   81BHP       Manual  Petrol
# 1   55,083 miles   1.1L   62BHP       Manual  Petrol
# 2  104,500 miles   1.4L   88BHP       Manual  Petrol
# 3  131,500 miles   1.6L   115PS       Manual  Petrol
# 5   92,308 miles   2.0L  115BHP       Manual  Petrol

# %%
df = df.drop('Unnamed: 0', axis=1)
df.head()
# Out:
#         makes   Price       Rating  Year       Type          Miles Litres  \
# 0        Ford  £6,922   Good price  2016  Hatchback   28,122 miles  1.25L
# 1     Hyundai    £890          NaN  2007  Hatchback   55,083 miles   1.1L
# 2     Peugeot  £1,000          NaN  2004  Hatchback  104,500 miles   1.4L
# 3    Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 5  Volkswagen    £650          NaN  2001     Saloon   92,308 miles   2.0L
#
#       BHP Transmission    Fuel
# 0   81BHP       Manual  Petrol
# 1   62BHP       Manual  Petrol
# 2   88BHP       Manual  Petrol
# 3   115PS       Manual  Petrol
# 5  115BHP       Manual  Petrol

# %%
df['Rating'].unique()
# Out:
# array(['Good price', nan, 'Great price', 'Lower price', 'Higher price'],
#       dtype=object)

# %%
df[df.Rating == 'Great price']
# Out:
#            makes   Price       Rating  Year       Type          Miles Litres  \
# 3       Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 16      Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 29      Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 42      Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 55      Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# ...          ...     ...          ...   ...        ...            ...    ...
# 115248  Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 115261  Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 115274  Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 115287  Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
# 115300  Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
#
#           BHP Transmission    Fuel
# ...

# %%
df[df.Rating == 'Great price'].drop_duplicates()
# Out:
#       makes   Price       Rating  Year       Type          Miles Litres  \
# 3  Vauxhall  £2,000  Great price  2009  Hatchback  131,500 miles   1.6L
#
#      BHP Transmission    Fuel
# 3  115PS       Manual  Petrol

# %%
df[df.Rating == 'Good price'].drop_duplicates()
# Out:
#       makes   Price      Rating  Year       Type         Miles Litres    BHP  \
# 0      Ford  £6,922  Good price  2016  Hatchback  28,122 miles  1.25L  81BHP
# 12  Hyundai  £5,993  Good price  2017  Hatchback  26,921 miles   1.0L   66PS
#
#    Transmission    Fuel
# 0        Manual  Petrol
# 12       Manual  Petrol

# %%
df[df.Rating == 'Lower price'].drop_duplicates()
# Out:
#   makes   Price       Rating  Year    Type          Miles Litres     BHP  \
# 7  Saab  £1,795  Lower price  2009  Saloon  135,000 miles   1.9L  178BHP
#
#   Transmission    Fuel
# 7       Manual  Diesel

# %%
df[df.Rating == 'Higher price'].drop_duplicates()
# Out:
#             makes    Price        Rating  Year Type         Miles Litres  \
# 11  Mercedes-Benz  £19,850  Higher price  2015  SUV  49,410 miles   2.1L
#
#        BHP Transmission    Fuel
# 11  168BHP    Automatic  Diesel

# %% [markdown]
# Looks like the once with a 'rating' were ads of some sort, let's get rid of the duplicates

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#             makes    Price        Rating  Year       Type          Miles  \
# 0            Ford   £6,922    Good price  2016  Hatchback   28,122 miles
# 1         Hyundai     £890           NaN  2007  Hatchback   55,083 miles
# 2         Peugeot   £1,000           NaN  2004  Hatchback  104,500 miles
# 3        Vauxhall   £2,000   Great price  2009  Hatchback  131,500 miles
# 5      Volkswagen     £650           NaN  2001     Saloon   92,308 miles
# 6        Vauxhall     £500           NaN  2006        MPV  152,990 miles
# 7            Saab   £1,795   Lower price  2009     Saloon  135,000 miles
# 8          Toyota   £1,000           NaN  1999      Coupe  104,500 miles
# 9      Volkswagen   £1,958           NaN  2006  Hatchback   65,290 miles
# 10        Peugeot     £850           NaN  2005  Hatchback   61,000 miles
# 11  Mercedes-Benz  £19,850  Higher price  2015        SUV   49,410 miles
# 12        Hyundai   £5,993    Good price  2017  Hatchback   26,921 miles
#
# ...
