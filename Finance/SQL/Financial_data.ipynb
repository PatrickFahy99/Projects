# %%
import sqlite3

conn = sqlite3.connect('financialdata.db')
c = conn.cursor()

c.execute('''
    SELECT * FROM FB;
    ''').fetchall()
# Out:
# [('2012-05-18 00:00:00',
#   'FB',
#   45.0,
#   38.0,
#   42.04999923706055,
#   38.22999954223633,
#   573576400,
#   38.22999954223633),
#  ('2012-05-21 00:00:00',
#   'FB',
#   36.65999984741211,
#   33.0,
#   36.529998779296875,
#   34.029998779296875,
#   168192700,
#   34.029998779296875),
#  ('2012-05-22 00:00:00',
#   'FB',
#   33.59000015258789,
#   30.940000534057617,
#   32.61000061035156,
#   31.0,
#   101786600,
#   31.0),
#  ('2012-05-23 00:00:00',
#   'FB',
#   32.5,
#   31.360000610351562,
#   31.3700008392334,
#   32.0,
#   73600000,
#   32.0),
#  ('2012-05-24 00:00:00',
#   'FB',
#   33.209999084472656,
#   31.770000457763672,
#   32.95000076293945,
#   33.029998779296875,
#   50237200,
#   33.029998779296875),
#  ('2012-05-25 00:00:00',
#   'FB',
#   32.95000076293945,
#   31.110000610351562,
#   32.900001525878906,
#   31.90999984741211,
#   37149800,
#   31.90999984741211),
#  ('2012-05-29 00:00:00',
#   'FB',
#   31.690000534057617,
#   28.649999618530273,
# ...

# %%
c.execute('DESCRIBE FB')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-8e4794c7852a> in <module>
# ----> 1 c.execute('DESCRIBE FB')
#
# OperationalError: near "DESCRIBE": syntax error
